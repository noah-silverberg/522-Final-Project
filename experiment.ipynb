# %%
from resnet import resnet32
from train import train_and_evaluate_resnet
# Out:
# Using device: cpu

# %%
dropout_grid = [0.0, 0.1, 0.3, 0.5]
results = {}

for p in dropout_grid:
    print(f"\n=== Training ResNet-32 with dropout_p={p} ===")
    res = train_and_evaluate_resnet(
        depth=32,
        dropout_p=p,
        seed=42,          # later you can loop over multiple seeds
        batch_size=128,
        num_epochs=100,   # or shorter while debugging
        lr=0.1,
        out_dir="./checkpoints_resnet32_dropout",
    )
    results[p] = res
# Out:
# === Training ResNet-32 with dropout_p=0.0 ===
